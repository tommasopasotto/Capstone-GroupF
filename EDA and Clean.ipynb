# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_df = pd.read_csv("drive/MyDrive/Capstone/dataCorrect2222.csv",sep=";",parse_dates=['ValueDate'],dayfirst=True, encoding = "ISO-8859-1")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (20,25,26,32,34,38,40,44,46,48,50,52,53,54) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ## Initial EDA and Cleaning

# %%
data_df.sample(5)
# Out:
#                Id  ClientID    ClientDescription  OrganizationalUnitID  \
# 414827  1419312.0     330.0  Cliente anonimizado                 312.0
# 483082  1716411.0     460.0  Cliente anonimizado                 409.0
# 227674   719024.0     650.0  Cliente anonimizado                1004.0
# 261801   820825.0     180.0  Cliente anonimizado                 132.0
# 31513    321658.0     460.0  Cliente anonimizado                 409.0
#
#           OrganizationalUnitDescription  OrganizationalUnitTypeID  \
# 414827  Unidad organizativa anonimizada                       1.0
# 483082  Unidad organizativa anonimizada                      10.0
# 227674  Unidad organizativa anonimizada                       3.0
# 261801  Unidad organizativa anonimizada                       1.0
# 31513   Unidad organizativa anonimizada                      10.0
#
#        OrganizationalUnitTypeDescription  SourceID  \
# 414827                           Holding       NaN
# 483082                        Delegación   11180.0
# 227674                           Oficina   21130.0
# 261801                           Holding   21400.0
# 31513                         Delegación   10730.0
#
#                   SourceDescription  ValueDate  ...  WasteTypeID  \
# 414827                          NaN 2021-10-01  ...          NaN
# 483082  0007078837313221928 Gasoleo 2022-03-01  ...          NaN
# 227674          Consumo gas natural 2019-04-01  ...          NaN
# 261801    4574-LPB Consumo gasolina 2021-05-01  ...          NaN
# 31513   0007078835341314251 Gasoleo 2019-02-01  ...          NaN
#
#         WasteTypeDescription  WasteTreatmentID WasteTreatmentDescription  \
# 414827                   NaN               NaN                       NaN
# 483082                   NaN               NaN                       NaN
# 227674                   NaN               NaN                       NaN
# 261801                   NaN               NaN                       NaN
# 31513                    NaN               NaN                       NaN
#
#         TransportID        TransportDescription  TransportTypeID  \
# 414827         19.0  Coche diesel grande(>2.0l)              3.0
# 483082          NaN                         NaN              NaN
# 227674          NaN                         NaN              NaN
# 261801          NaN                         NaN              NaN
# 31513           NaN                         NaN              NaN
#
#        TransportTypeDescription  BiogenicEmission Renovable
# 414827                Carretera             False     False
# 483082                      NaN             False     False
# 227674                      NaN             False     False
# 261801                      NaN             False     False
# 31513                       NaN             False       NaN
#
# [5 rows x 55 columns]

# %%
#Check data types of columns
pd.DataFrame(data_df.columns, data_df.dtypes)
# Out:
#                                                 0
# float64                                        Id
# float64                                  ClientID
# object                          ClientDescription
# float64                      OrganizationalUnitID
# object              OrganizationalUnitDescription
# float64                  OrganizationalUnitTypeID
# object          OrganizationalUnitTypeDescription
# float64                                  SourceID
# object                          SourceDescription
# datetime64[ns]                          ValueDate
# float64                                     Month
# float64                                      Year
# float64                                  PeriodID
# object                          PeriodDescription
# float64                             AspectGroupID
# object                     AspectGroupDescription
# float64                                  FactorID
# object                          FactorDescription
# float64                                  AspectID
# object                          AspectDescription
# object                                      Value
# float64                                    UnitID
# object                            UnitDescription
# float64                                     GEIID
# object                             GEIDescription
# object                            LERCodeCodeUnit
# object                         LERCodeDescription
# float64                              EmitterGEIID
# object                      EmitterGEIDescription
# float64                                  VendorID
# object                                 VendorName
# float64                        RawMaterialGroupID
# object                RawMaterialGroupDescription
# float64                       RawMaterialOriginID
# object               RawMaterialOriginDescription
# float64                          DisposalMethodID
# float64                 DisposalMethodDescription
# float64                               WaterUsesID
# object                       WaterUsesDescription
# float64                             WaterOriginID
# object                     WaterOriginDescription
# float64                                   ScopeID
# object                           ScopeDescription
# float64                                FuelTypeID
# object                        FuelTypeDescription
# float64                               WasteTypeID
# object                       WasteTypeDescription
# float64                          WasteTreatmentID
# object                  WasteTreatmentDescription
# float64                               TransportID
# object                       TransportDescription
# float64                           TransportTypeID
# object                   TransportTypeDescription
# object                           BiogenicEmission
# object                                  Renovable

# %%
#show shape of our the dataset
data_df.shape
# Out:
# (514271, 55)

# %%
#check for null values
pd.DataFrame(data_df.isnull().sum()).sort_values(0,ascending = True)
# Out:
#                                         0
# FactorDescription                      48
# AspectGroupDescription                 48
# Year                                   73
# ClientID                               85
# ClientDescription                      85
# Id                                     97
# AspectDescription                      97
# AspectID                               97
# FactorID                               97
# AspectGroupID                          97
# PeriodDescription                      97
# PeriodID                               97
# ValueDate                              97
# OrganizationalUnitTypeDescription      97
# OrganizationalUnitTypeID               97
# OrganizationalUnitDescription          97
# OrganizationalUnitID                   97
# Month                                  97
# Value                                 109
# UnitID                                109
# UnitDescription                       109
# BiogenicEmission                      194
# SourceDescription                   11411
# SourceID                            11411
# VendorID                            34098
# VendorName                          34098
# EmitterGEIID                        34715
# EmitterGEIDescription               34833
# GEIDescription                     156401
# GEIID                              156450
# ScopeDescription                   156474
# ScopeID                            156474
# Renovable                          204785
# LERCodeDescription                 502952
# LERCodeCodeUnit                    502952
# TransportTypeDescription           502957
# TransportTypeID                    502957
# TransportID                        502957
# TransportDescription               502957
# WasteTypeID                        503268
# WasteTypeDescription               503268
# WasteTreatmentID                   508161
# WasteTreatmentDescription          508161
# WaterOriginDescription             514020
# WaterUsesID                        514020
# WaterUsesDescription               514020
# WaterOriginID                      514020
# RawMaterialOriginDescription       514097
# RawMaterialOriginID                514109
# RawMaterialGroupDescription        514109
# RawMaterialGroupID                 514109
# FuelTypeDescription                514193
# FuelTypeID                         514193
# DisposalMethodDescription          514271
# DisposalMethodID                   514271

# %%
data_df.head()
# Out:
#        Id  ClientID    ClientDescription  OrganizationalUnitID  \
# 0  7958.0      30.0  Cliente anonimizado                  18.0
# 1  7959.0      30.0  Cliente anonimizado                  18.0
# 2  7960.0      30.0  Cliente anonimizado                  18.0
# 3  7961.0      30.0  Cliente anonimizado                  18.0
# 4  7962.0      30.0  Cliente anonimizado                  18.0
#
#      OrganizationalUnitDescription  OrganizationalUnitTypeID  \
# 0  Unidad organizativa anonimizada                       3.0
# 1  Unidad organizativa anonimizada                       3.0
# 2  Unidad organizativa anonimizada                       3.0
# 3  Unidad organizativa anonimizada                       3.0
# 4  Unidad organizativa anonimizada                       3.0
#
#   OrganizationalUnitTypeDescription  SourceID SourceDescription  ValueDate  \
# 0                           Oficina      18.0     Consumo toner 2017-01-01
# 1                           Oficina      18.0     Consumo toner 2017-02-01
# 2                           Oficina      18.0     Consumo toner 2017-03-01
# 3                           Oficina      18.0     Consumo toner 2017-04-01
# 4                           Oficina      18.0     Consumo toner 2017-05-01
#
#    ...  WasteTypeID  WasteTypeDescription  WasteTreatmentID  \
# 0  ...          NaN                   NaN               NaN
# 1  ...          NaN                   NaN               NaN
# 2  ...          NaN                   NaN               NaN
# 3  ...          NaN                   NaN               NaN
# 4  ...          NaN                   NaN               NaN
#
#   WasteTreatmentDescription  TransportID TransportDescription  \
# 0                       NaN          NaN                  NaN
# 1                       NaN          NaN                  NaN
# 2                       NaN          NaN                  NaN
# 3                       NaN          NaN                  NaN
# 4                       NaN          NaN                  NaN
#
#    TransportTypeID TransportTypeDescription  BiogenicEmission Renovable
# 0              NaN                      NaN             False     False
# 1              NaN                      NaN             False     False
# 2              NaN                      NaN             False     False
# 3              NaN                      NaN             False     False
# 4              NaN                      NaN             False     False
#
# [5 rows x 55 columns]

# %%
#! pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(data_df)
profile.to_notebook_iframe()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Sanity Check if Id and Description matchs for all Columns
# As we have duplicate columns for Id and description we tried to check if both Id and description match. This is necessary to decide which columns to use and which columns to ignore.

# %%
data_df["UnitID"].value_counts()
# Out:
# 7.0     362157
# 2.0      93481
# 4.0      27205
# 1.0      17217
# 6.0       7195
# 5.0       5657
# 45.0       178
# 36.0       174
# 21.0       172
# 50.0       144
# 47.0       103
# 51.0       101
# 56.0        80
# 58.0        72
# 46.0        66
# 27.0        43
# 18.0        24
# 59.0        24
# 60.0        24
# 41.0        18
# 13.0        14
# 15.0        12
# 44.0         1
# Name: UnitID, dtype: int64

# %%
data_df["UnitDescription"].value_counts()
# Out:
# t             362157
# l              93481
# kWh            27205
# kg             17217
# m3              7195
# km              5657
# Ud               178
# Informe          174
# Copias           172
# MWh              144
# Horas            103
# ha               101
# pue               80
# m2                72
# Noche             66
#                  43
# Paquete A4        24
# gal               24
# th                24
# Folio             18
# UdT               14
# Paq.folios        12
# ptos               1
# Name: UnitDescription, dtype: int64

# %%
data_df["ClientID"].nunique()
# Out:
# 58

# %%
data_df["ClientID"].unique()
# Out:
# array([3.00e+01, 7.00e+01, 1.20e+02, 1.30e+02, 1.60e+02, 1.70e+02,
#        1.40e+02, 2.10e+02, 1.90e+02, 2.00e+02, 2.30e+02, 2.40e+02,
#        2.60e+02, 2.50e+02, 3.66e+17, 3.54e+17, 3.31e+17,      nan,
#        2.80e+02, 3.10e+02, 3.00e+02, 3.30e+02, 3.40e+02, 3.50e+02,
#        3.60e+02, 4.00e+02, 4.30e+02, 3.70e+02, 3.90e+02, 3.80e+02,
#        4.50e+02, 4.60e+02, 4.80e+02, 4.70e+02, 5.00e+02, 4.90e+02,
#        5.30e+02, 5.20e+02, 5.10e+02, 5.50e+02, 5.40e+02, 5.70e+02,
#        5.90e+02, 5.80e+02, 1.80e+02, 6.00e+02, 6.20e+02, 6.30e+02,
#        6.10e+02, 6.80e+02, 6.50e+02, 6.90e+02, 7.00e+02, 7.10e+02,
#        7.40e+02, 7.50e+02, 7.60e+02, 7.70e+02, 7.80e+02])

# %%
data_df = data_df[(data_df["ClientID"].notna()) & (~data_df["ClientID"].isin([3.66e+17, 3.54e+17, 3.31e+17]))]

# %%
data_df["ClientID"].unique()
# Out:
# array([ 30.,  70., 120., 130., 160., 170., 140., 210., 190., 200., 230.,
#        240., 260., 250., 280., 310., 300., 330., 340., 350., 360., 400.,
#        430., 370., 390., 380., 450., 460., 480., 470., 500., 490., 530.,
#        520., 510., 550., 540., 570., 590., 580., 180., 600., 620., 630.,
#        610., 680., 650., 690., 700., 710., 740., 750., 760., 770., 780.])

# %%
data_df["ClientID"].nunique()
# Out:
# 55

# %% [markdown]
# We have 55 unique clients data

# %%
data_df["ClientDescription"].value_counts()
# Out:
# Cliente anonimizado    514174
# Name: ClientDescription, dtype: int64

# %% [markdown]
# However the descritpion of the client is not given due to privacy

# %%
data_df["OrganizationalUnitID"].value_counts()
# Out:
# 414.0     131770
# 409.0      96396
# 412.0      44393
# 411.0      32744
# 410.0      32144
#            ...
# 1565.0         3
# 1054.0         2
# 114.0          2
# 109.0          2
# 396.0          2
# Name: OrganizationalUnitID, Length: 474, dtype: int64

# %% [markdown]
# We have 474 unique organizational unit

# %%
data_df["OrganizationalUnitDescription"].value_counts()
# Out:
# Unidad organizativa anonimizada    514174
# Name: OrganizationalUnitDescription, dtype: int64

# %% [markdown]
# However the descritpion of the organizational unit is not given due to privacy

# %%
data_df["OrganizationalUnitTypeID"].value_counts()
# Out:
# 10.0    338835
# 28.0     56724
# 3.0      36102
# 1.0      25030
# 24.0     10362
# 25.0      9549
# 32.0      6032
# 4.0       5940
# 13.0      4866
# 7.0       3825
# 6.0       3241
# 12.0      2389
# 19.0      2107
# 2.0       1424
# 20.0      1128
# 35.0      1052
# 31.0      1004
# 21.0       961
# 5.0        857
# 26.0       752
# 23.0       491
# 8.0        435
# 18.0       384
# 22.0       236
# 9.0        192
# 33.0       108
# 29.0        96
# 34.0        40
# 17.0        12
# Name: OrganizationalUnitTypeID, dtype: int64

# %%
data_df["OrganizationalUnitTypeDescription"].value_counts()
# Out:
# Delegación              338835
# Espacio oficina          56724
# Oficina                  36102
# Holding                  25030
# Bodega                   10362
# Viñedo                    9549
# Espacio terminal          6032
# Fábrica                   5940
# Edificio                  4866
# Planta industrial         3825
# Proyecto                  3241
# Hotel                     2389
# Centro I+D                2107
# Sociedad                  1424
# Centro de producción      1128
# Laboratorio               1052
# Espacio almacén           1004
# Campus                     961
# Punto de venta             857
# Parque eólico              752
# Producción                 491
# Almacén                    435
# Evento                     384
# Obra                       236
# Linea de negocio           192
# País                       108
# Terminal                    96
# Plató                       40
# Empleado                    12
# Name: OrganizationalUnitTypeDescription, dtype: int64

# %% [markdown]
# We have the same number of values for organizational unit type id and organizational unit type description.
#
# Analysis to do here:
# * Which client has the most number of organizational unit
# * Which client has the most co2 emission value
# * Which orginazational unit has the most co2 emission value
# * The average number of orginazational unit per client
# * Which orginational type has the most co2 emission value

# %%
client_orga = data_df.groupby(['ClientID'])[['OrganizationalUnitID']].nunique().reset_index().sort_values(by="OrganizationalUnitID",ascending=False)

# %%
client_orga.head(10)
# Out:
#     ClientID  OrganizationalUnitID
# 42     610.0                   148
# 47     690.0                    87
# 7      180.0                    40
# 3      130.0                    18
# 26     430.0                    17
# 13     250.0                    14
# 25     400.0                    12
# 0       30.0                    11
# 18     330.0                    10
# 22     370.0                     9

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
fig,ax = plt.subplots(figsize=(15,10))
ax=sns.barplot(y="ClientID",x = 'OrganizationalUnitID', 
          order=client_orga.sort_values('OrganizationalUnitID',ascending=False).ClientID,
              orient='h', 
              data=client_orga, 
              ax=ax, 
              palette='crest')


for p in ax.patches:
    width = p.get_width()    
    ax.text(width + 1,       # 
            p.get_y() + p.get_height() / 2,
            '{:1.0f}'.format(width),
            ha = 'left',
            va = 'center',
            size=9) 
plt.xticks(rotation=45)
plt.show()

# %%
average_orga_per_client = data_df['OrganizationalUnitID'].nunique() /data_df['ClientID'].nunique()

# %%
average_orga_per_client
# Out:
# 8.618181818181819

# %%
data_df['SourceID'].value_counts()
# Out:
# 11464.0    1474
# 14247.0    1455
# 11527.0    1429
# 10689.0    1395
# 11393.0    1395
#            ...
# 27373.0       1
# 10336.0       1
# 27351.0       1
# 27330.0       1
# 27391.0       1
# Name: SourceID, Length: 5737, dtype: int64

# %%
data_df['SourceDescription'].value_counts()
# Out:
# Consumo eléctrico oficinas              13090
# Consumo eléctrico                       10520
# Consumo gasóleo A                        4738
# Suministro eléctrico                     4143
# Consumo agua                             3305
#                                         ...
# Productos enológicos obsoletos              1
# Lodos de lavado y limpieza Verinsur         1
# Sacos Big Bag contaminados                  1
# Cartuchos tinta                             1
# 0007078836114128472 adblue                  1
# Name: SourceDescription, Length: 3933, dtype: int64

# %%
data_df['ValueDate'].isna().sum()
# Out:
# 0

# %%
data_df['ValueDate'].dt.day.nunique()
# Out:
# 1

# %% [markdown]
# We wont be using this column because we have the same value in column year and month

# %%
data_df['Month'].value_counts()
# Out:
# 2.0     54622
# 3.0     53607
# 1.0     52298
# 9.0     44731
# 11.0    43252
# 6.0     40682
# 7.0     40590
# 8.0     38541
# 5.0     38310
# 12.0    37778
# 4.0     35088
# 10.0    34675
# Name: Month, dtype: int64

# %%
data_df['Year'].value_counts()
# Out:
# 2021.0    210857
# 2020.0    149054
# 2019.0     95870
# 2022.0     44046
# 2018.0      7290
# 2017.0      4382
# 2016.0      1753
# 2015.0       649
# 2014.0       261
# 2013.0        12
# Name: Year, dtype: int64

# %%
data_df['PeriodID'].value_counts()
# Out:
# 168.0    133971
# 169.0     91170
# 170.0     78729
# 246.0     37131
# 153.0     20516
#           ...
# 173.0         2
# 186.0         2
# 230.0         2
# 197.0         2
# 133.0         1
# Name: PeriodID, Length: 180, dtype: int64

# %%
data_df['PeriodDescription'].value_counts()
# Out:
# Año 2021     210398
# Año 2020     148254
# Año 2019      95963
# Año 2022      43863
# Año 2018       5448
# Año 2017       3373
# FY 2016         948
# FY 2017         888
# FY 2018         775
# Año 2016        654
# FY 2019         615
# FY 2020         568
# FY 2021         492
# Año 2015        412
# FY 2022         289
# Year 2020       284
# Año 2014        261
# Year 2019       215
# Year 2016       166
# Year 2018       153
# Year 2017       143
# Año 2013         12
# Name: PeriodDescription, dtype: int64

# %%
data_df['AspectGroupID'].value_counts()
# Out:
# 3.0     388127
# 1.0      54848
# 11.0     26692
# 5.0      13257
# 6.0      12079
# 10.0     11314
# 2.0       7072
# 12.0       749
# 8.0         36
# Name: AspectGroupID, dtype: int64

# %%
data_df['AspectGroupDescription'].value_counts()
# Out:
# Combustible                     388127
# Electricidad                     54848
# Indicadores                      26692
# Residuos                         13257
# Materias primas                  12079
# Viajes                           11314
# Agua                              7072
# Emisiones                          749
# Emisiones bienes y servicios        36
# Name: AspectGroupDescription, dtype: int64

# %%
data_df['FactorID'].value_counts()
# Out:
# 5.0    357797
# 1.0    111327
# 4.0     11949
# 3.0     10742
# 8.0      9594
# 2.0      7072
# 7.0      5657
# 9.0        36
# Name: FactorID, dtype: int64

# %%
data_df['FactorDescription'].value_counts()
# Out:
# Emisiones             357797
# Energía               111327
# Residuos               11949
# Materias Primas        10742
# Indicadores             9594
# Agua y Efluentes        7072
# Viajes                  5657
# Emisiones evitadas        36
# Name: FactorDescription, dtype: int64

# %%
data_df['AspectID'].value_counts()
# Out:
# 77.0     295802
# 7.0       59077
# 1.0       54848
# 140.0     24422
# 79.0      13188
#           ...
# 205.0         1
# 216.0         1
# 212.0         1
# 174.0         1
# 231.0         1
# Name: AspectID, Length: 217, dtype: int64

# %%
data_df['AspectDescription'].value_counts()
# Out:
# Consumo gasóleo A                 295802
# Consumo gasolina                   59077
# Consumo eléctrico                  54848
# Consumo GLP                        24422
# Consumo gasóleo A (A3)             13188
#                                    ...
# Residuos químicos                      1
# Consumo fuelóleo                       1
# Tintas pastosas                        1
# Productos enológicos obsoletos         1
# Resinas                                1
# Name: AspectDescription, Length: 216, dtype: int64

# %% [markdown]
# ## Target Value Analysis

# %%
data_df['Value']
# Out:
# 0         0.169863014
# 1         0.153424658
# 2         0.169863014
# 3         0.164383562
# 4         0.169863014
#              ...
# 514266        0.96264
# 514267           8022
# 514268        115.968
# 514269        115.968
# 514270           9664
# Name: Value, Length: 514174, dtype: object

# %%
#change data type of value to numeric and handle numerical structure of value
data_df['new_value'] = data_df.apply(lambda row: ".".join(str(row['Value']).replace(",",'.').split('.')[:2]), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data_df['new_value']
# Out:
# 0         0.169863014
# 1         0.153424658
# 2         0.169863014
# 3         0.164383562
# 4         0.169863014
#              ...
# 514266        0.96264
# 514267           8022
# 514268        115.968
# 514269        115.968
# 514270           9664
# Name: new_value, Length: 514174, dtype: object

# %%
# distriution of value
plt.figure(figsize=(20,8))
data_df['new_value'].astype(float).plot.hist(bins=50,range=(0,30_000_000),color='green')
plt.show()

# %%
#show the distribution range
data_df['new_value'].loc[(data_df['new_value'] > 0) & (data_df['new_value'] < 52)].shape[0]/len(data_df)
# Out:
# 0.8722455822348076

# %%
data_df['new_value'] = data_df['new_value'].astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# As we can see from the graph most of the values are skewed left and the values are close to zero.

# %%
data_df.groupby(['ClientID']).agg({"new_value":"sum"}).reset_index().sort_values(by="new_value",ascending=False)
# Out:
#     ClientID     new_value
# 7      180.0  5.714164e+08
# 29     470.0  3.233105e+08
# 14     260.0  1.829928e+08
# 12     240.0  8.422230e+07
# 8      190.0  5.536792e+07
# 15     280.0  4.715223e+07
# 42     610.0  2.231837e+07
# 24     390.0  8.862316e+06
# 2      120.0  4.414952e+06
# 28     460.0  3.405380e+06
# 13     250.0  3.343361e+06
# 1       70.0  3.203133e+06
# 44     630.0  2.585078e+06
# 3      130.0  2.542407e+06
# 52     760.0  2.464556e+06
# 26     430.0  1.746545e+06
# 11     230.0  1.323121e+06
# 47     690.0  1.302478e+06
# 53     770.0  1.017957e+06
# 5      160.0  8.627290e+05
# 50     740.0  7.810353e+05
# 54     780.0  6.989082e+05
# 23     380.0  6.335427e+05
# 48     700.0  4.343299e+05
# 51     750.0  4.027916e+05
# 30     480.0  3.699298e+05
# 21     360.0  3.505250e+05
# 0       30.0  3.278820e+05
# 9      200.0  3.218301e+05
# 40     590.0  3.073438e+05
# 18     330.0  3.027737e+05
# 46     680.0  3.024961e+05
# 41     600.0  2.485900e+05
# 36     540.0  2.283814e+05
# 39     580.0  2.278721e+05
# 33     510.0  1.350295e+05
# 43     620.0  1.344114e+05
# 38     570.0  1.331489e+05
# 17     310.0  1.026467e+05
# 25     400.0  8.586195e+04
# 19     340.0  8.357780e+04
# 34     520.0  7.154668e+04
# 45     650.0  7.025804e+04
# 32     500.0  5.411599e+04
# 49     710.0  3.480544e+04
# 31     490.0  3.127523e+04
# 37     550.0  2.910932e+04
# 22     370.0  2.072141e+04
# 20     350.0  9.769152e+03
# 6      170.0  8.118459e+03
# 16     300.0  6.422989e+03
# 4      140.0  3.527370e+03
# 10     210.0  1.470536e+03
# 35     530.0  1.117737e+03
# 27     450.0  9.401560e+02

# %%
fig,ax = plt.subplots(figsize=(19,12))
sns.color_palette("crest", as_cmap=True)
ax=sns.barplot(y="ClientID",x = 'new_value', 
               orient='h', 
          order=data_df.groupby(['ClientID']).agg({"new_value":"sum"}).reset_index().head(10).sort_values('new_value',ascending=False).ClientID,
              data=data_df.groupby(['ClientID']).agg({"new_value":"sum"}).reset_index().head(10), 
              ax=ax,palette="crest")


for p in ax.patches:
    width = p.get_width()    
    ax.text(width + 1,       # 
            p.get_y() + p.get_height() / 2,
            '{:1.0f}'.format(width),
            ha = 'left',
            va = 'center',
            size=9) 
plt.xticks(rotation=45)
plt.show()

# %%
data_df.groupby(['ClientID','OrganizationalUnitID']).agg({"new_value":"sum"}).reset_index().sort_values(by="new_value",ascending=False)
# Out:
#      ClientID  OrganizationalUnitID     new_value
# 61      180.0                 434.0  3.579542e+08
# 183     470.0                 440.0  3.233105e+08
# 106     260.0                 220.0  1.805457e+08
# 43      180.0                 135.0  8.369363e+07
# 90      240.0                 165.0  6.567993e+07
# ..        ...                   ...           ...
# 305     610.0                 827.0  4.990000e-01
# 300     610.0                 817.0  7.485000e-02
# 301     610.0                 819.0  4.990000e-02
# 425     690.0                1565.0  7.819396e-03
# 204     570.0                 502.0  0.000000e+00
#
# [474 rows x 3 columns]

# %%
fig,ax = plt.subplots(figsize=(19,12))
ax=sns.barplot(y="OrganizationalUnitID",x = 'new_value', 
               orient='h', 
          order=data_df.groupby(['ClientID','OrganizationalUnitID']).agg({"new_value":"sum"}).reset_index().head(10).sort_values('new_value',ascending=False).OrganizationalUnitID,
              data=data_df.groupby(['ClientID','OrganizationalUnitID']).agg({"new_value":"sum"}).reset_index().head(10), 
              ax=ax,palette='crest')


for p in ax.patches:
    width = p.get_width()    
    ax.text(width + 1,       # 
            p.get_y() + p.get_height() / 2,
            '{:1.0f}'.format(width),
            ha = 'left',
            va = 'center',
            size=9) 
plt.xticks(rotation=45)
plt.show()

# %%
orga_year = data_df.groupby(['OrganizationalUnitID','Year']).agg({"new_value":"sum"}).reset_index().sort_values(by="new_value",ascending=False)
orga_year
# Out:
#      OrganizationalUnitID    Year     new_value
# 406                 440.0  2020.0  3.224508e+08
# 400                 434.0  2021.0  1.476181e+08
# 399                 434.0  2020.0  1.388137e+08
# 168                 220.0  2020.0  7.159070e+07
# 169                 220.0  2021.0  5.624291e+07
# ..                    ...     ...           ...
# 954                1556.0  2021.0  2.085172e-03
# 484                 501.0  2019.0  0.000000e+00
# 486                 502.0  2019.0  0.000000e+00
# 487                 502.0  2020.0  0.000000e+00
# 391                 432.0  2019.0  0.000000e+00
#
# [1121 rows x 3 columns]

# %%
fig,ax = plt.subplots(figsize=(19,12))
ax=sns.barplot(y="OrganizationalUnitID",x = 'new_value',hue='Year',
               orient='h', 
              data=orga_year.head(10), 
              ax=ax,palette='crest')


for p in ax.patches:
    width = p.get_width()    
    ax.text(width + 1,       # 
            p.get_y() + p.get_height() / 2,
            '{:1.0f}'.format(width),
            ha = 'left',
            va = 'center',
            size=9) 
plt.xticks(rotation=45)
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
orga_month = data_df.groupby(['OrganizationalUnitID','Month']).agg({"new_value":"sum"}).reset_index().sort_values(by="new_value",ascending=False)
orga_month
# Out:
#       OrganizationalUnitID  Month     new_value
# 1355                 434.0   10.0  5.701680e+07
# 1349                 434.0    4.0  5.542185e+07
# 1356                 434.0   11.0  4.358633e+07
# 1350                 434.0    5.0  3.747639e+07
# 1348                 434.0    3.0  3.744795e+07
# ...                    ...    ...           ...
# 4415                1583.0    6.0 -1.736825e+02
# 4497                1591.0    5.0 -1.854925e+02
# 4363                1578.0    5.0 -4.076747e+02
# 4421                1583.0   12.0 -4.146429e+02
# 773                  315.0    5.0 -7.101217e+02
#
# [4930 rows x 3 columns]

# %%
fig,ax = plt.subplots(figsize=(19,12))
ax=sns.barplot(y="OrganizationalUnitID",x = 'new_value',hue='Month',
               orient='h', 
              data=orga_month.head(25), 
              ax=ax,palette='crest')


for p in ax.patches:
    width = p.get_width()    
    ax.text(width + 1,       # 
            p.get_y() + p.get_height() / 2,
            '{:1.0f}'.format(width),
            ha = 'left',
            va = 'center',
            size=9) 
plt.xticks(rotation=45)
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values

# %%
client_year_month = data_df.groupby(['ClientID','Year','Month']).agg({"new_value":"sum"}).reset_index().sort_values(by="new_value",ascending=False)
client_year_month
# Out:
#       ClientID    Year  Month     new_value
# 393      180.0  2021.0   10.0  3.731550e+07
# 1119     470.0  2020.0    3.0  3.060977e+07
# 374      180.0  2020.0    3.0  2.984727e+07
# 389      180.0  2021.0    6.0  2.982650e+07
# 388      180.0  2021.0    5.0  2.936631e+07
# ...        ...     ...    ...           ...
# 562      210.0  2018.0    7.0  1.147000e+00
# 749      280.0  2021.0    7.0  1.015000e+00
# 927      350.0  2020.0    5.0  4.843750e-01
# 1466     690.0  2018.0   11.0  1.764706e-01
# 928      350.0  2020.0    6.0 -3.448413e+02
#
# [1660 rows x 4 columns]

# %%
data_df.isna().sum()
# Out:
# Id                                        0
# ClientID                                  0
# ClientDescription                         0
# OrganizationalUnitID                      0
# OrganizationalUnitDescription             0
# OrganizationalUnitTypeID                  0
# OrganizationalUnitTypeDescription         0
# SourceID                              11314
# SourceDescription                     11314
# ValueDate                                 0
# Month                                     0
# Year                                      0
# PeriodID                                  0
# PeriodDescription                         0
# AspectGroupID                             0
# AspectGroupDescription                    0
# FactorID                                  0
# FactorDescription                         0
# AspectID                                  0
# AspectDescription                         0
# Value                                    12
# UnitID                                   12
# UnitDescription                          12
# GEIID                                156353
# GEIDescription                       156353
# LERCodeCodeUnit                      502855
# LERCodeDescription                   502855
# EmitterGEIID                          34618
# EmitterGEIDescription                 34736
# VendorID                              34001
# VendorName                            34001
# RawMaterialGroupID                   514012
# RawMaterialGroupDescription          514012
# RawMaterialOriginID                  514012
# RawMaterialOriginDescription         514012
# DisposalMethodID                     514174
# DisposalMethodDescription            514174
# WaterUsesID                          513923
# WaterUsesDescription                 513923
# WaterOriginID                        513923
# WaterOriginDescription               513923
# ScopeID                              156377
# ScopeDescription                     156377
# FuelTypeID                           514096
# FuelTypeDescription                  514096
# WasteTypeID                          503171
# WasteTypeDescription                 503171
# WasteTreatmentID                     508064
# WasteTreatmentDescription            508064
# TransportID                          502860
# TransportDescription                 502860
# TransportTypeID                      502860
# TransportTypeDescription             502860
# BiogenicEmission                         97
# Renovable                            204688
# new_value                                12
# dtype: int64

# %%
data_df.loc[data_df['Id'] == 7965.0]
# Out:
#        Id  ClientID    ClientDescription  OrganizationalUnitID  \
# 0  7958.0      30.0  Cliente anonimizado                  18.0
#
#      OrganizationalUnitDescription  OrganizationalUnitTypeID  \
# 0  Unidad organizativa anonimizada                       3.0
#
#   OrganizationalUnitTypeDescription  SourceID SourceDescription  ValueDate  \
# 0                           Oficina      18.0     Consumo toner 2017-01-01
#
#    ...  WasteTypeDescription  WasteTreatmentID  WasteTreatmentDescription  \
# 0  ...                   NaN               NaN                        NaN
#
#   TransportID  TransportDescription TransportTypeID  TransportTypeDescription  \
# 0         NaN                   NaN             NaN                       NaN
#
#   BiogenicEmission  Renovable new_value
# 0            False      False  0.169863
#
# [1 rows x 56 columns]

# %%
data_df.head()
# Out:
#        Id  ClientID    ClientDescription  OrganizationalUnitID  \
# 0  7958.0      30.0  Cliente anonimizado                  18.0
# 1  7959.0      30.0  Cliente anonimizado                  18.0
# 2  7960.0      30.0  Cliente anonimizado                  18.0
# 3  7961.0      30.0  Cliente anonimizado                  18.0
# 4  7962.0      30.0  Cliente anonimizado                  18.0
#
#      OrganizationalUnitDescription  OrganizationalUnitTypeID  \
# 0  Unidad organizativa anonimizada                       3.0
# 1  Unidad organizativa anonimizada                       3.0
# 2  Unidad organizativa anonimizada                       3.0
# 3  Unidad organizativa anonimizada                       3.0
# 4  Unidad organizativa anonimizada                       3.0
#
#   OrganizationalUnitTypeDescription  SourceID SourceDescription  ValueDate  \
# 0                           Oficina      18.0     Consumo toner 2017-01-01
# 1                           Oficina      18.0     Consumo toner 2017-02-01
# 2                           Oficina      18.0     Consumo toner 2017-03-01
# 3                           Oficina      18.0     Consumo toner 2017-04-01
# 4                           Oficina      18.0     Consumo toner 2017-05-01
#
#    ...  WasteTypeDescription  WasteTreatmentID  WasteTreatmentDescription  \
# 0  ...                   NaN               NaN                        NaN
# 1  ...                   NaN               NaN                        NaN
# 2  ...                   NaN               NaN                        NaN
# 3  ...                   NaN               NaN                        NaN
# 4  ...                   NaN               NaN                        NaN
#
#   TransportID  TransportDescription TransportTypeID  TransportTypeDescription  \
# 0         NaN                   NaN             NaN                       NaN
# 1         NaN                   NaN             NaN                       NaN
# 2         NaN                   NaN             NaN                       NaN
# 3         NaN                   NaN             NaN                       NaN
# 4         NaN                   NaN             NaN                       NaN
#
#   BiogenicEmission  Renovable new_value
# 0            False      False  0.169863
# 1            False      False  0.153425
# 2            False      False  0.169863
# 3            False      False  0.164384
# 4            False      False  0.169863
#
# [5 rows x 56 columns]

# %%
data_df['Value'].isna().sum()
# Out:
# 12

# %%
data_df = data_df.loc[~data_df['Value'].isna()]

# %%
data_df.isna().sum()
# Out:
# Id                                        0
# ClientID                                  0
# ClientDescription                         0
# OrganizationalUnitID                      0
# OrganizationalUnitDescription             0
# OrganizationalUnitTypeID                  0
# OrganizationalUnitTypeDescription         0
# SourceID                              11314
# SourceDescription                     11314
# ValueDate                                 0
# Month                                     0
# Year                                      0
# PeriodID                                  0
# PeriodDescription                         0
# AspectGroupID                             0
# AspectGroupDescription                    0
# FactorID                                  0
# FactorDescription                         0
# AspectID                                  0
# AspectDescription                         0
# Value                                     0
# UnitID                                    0
# UnitDescription                           0
# GEIID                                156341
# GEIDescription                       156341
# LERCodeCodeUnit                      502843
# LERCodeDescription                   502843
# EmitterGEIID                          34606
# EmitterGEIDescription                 34724
# VendorID                              33989
# VendorName                            33989
# RawMaterialGroupID                   514000
# RawMaterialGroupDescription          514000
# RawMaterialOriginID                  514000
# RawMaterialOriginDescription         514000
# DisposalMethodID                     514162
# DisposalMethodDescription            514162
# WaterUsesID                          513911
# WaterUsesDescription                 513911
# WaterOriginID                        513911
# WaterOriginDescription               513911
# ScopeID                              156365
# ScopeDescription                     156365
# FuelTypeID                           514084
# FuelTypeDescription                  514084
# WasteTypeID                          503159
# WasteTypeDescription                 503159
# WasteTreatmentID                     508052
# WasteTreatmentDescription            508052
# TransportID                          502848
# TransportDescription                 502848
# TransportTypeID                      502848
# TransportTypeDescription             502848
# BiogenicEmission                         85
# Renovable                            204676
# new_value                                 0
# dtype: int64

# %%
data_df.dtypes
# Out:
# Id                                          float64
# ClientID                                    float64
# ClientDescription                            object
# OrganizationalUnitID                        float64
# OrganizationalUnitDescription                object
# OrganizationalUnitTypeID                    float64
# OrganizationalUnitTypeDescription            object
# SourceID                                    float64
# SourceDescription                            object
# ValueDate                            datetime64[ns]
# Month                                       float64
# Year                                        float64
# PeriodID                                    float64
# PeriodDescription                            object
# AspectGroupID                               float64
# AspectGroupDescription                       object
# FactorID                                    float64
# FactorDescription                            object
# AspectID                                    float64
# AspectDescription                            object
# Value                                        object
# UnitID                                      float64
# UnitDescription                              object
# GEIID                                       float64
# GEIDescription                               object
# LERCodeCodeUnit                              object
# LERCodeDescription                           object
# EmitterGEIID                                float64
# EmitterGEIDescription                        object
# VendorID                                    float64
# VendorName                                   object
# RawMaterialGroupID                          float64
# RawMaterialGroupDescription                  object
# RawMaterialOriginID                         float64
# RawMaterialOriginDescription                 object
# DisposalMethodID                            float64
# DisposalMethodDescription                   float64
# WaterUsesID                                 float64
# WaterUsesDescription                         object
# WaterOriginID                               float64
# WaterOriginDescription                       object
# ScopeID                                     float64
# ScopeDescription                             object
# FuelTypeID                                  float64
# FuelTypeDescription                          object
# WasteTypeID                                 float64
# WasteTypeDescription                         object
# WasteTreatmentID                            float64
# WasteTreatmentDescription                    object
# TransportID                                 float64
# TransportDescription                         object
# TransportTypeID                             float64
# TransportTypeDescription                     object
# BiogenicEmission                             object
# Renovable                                    object
# new_value                                   float64
# dtype: object

# %%
data_df["GEIDescription"].value_counts()
# Out:
# CO2eq       127648
# C02          93977
# CH4          67808
# N2O          67808
# R-410A         134
# R-407C         112
# HFC-134a        80
# R-449A          68
# R-407F          60
# R-404A          41
# R-407H          17
# R-422D          16
# R-448A          16
# R-424A          12
# R-453A           9
# R-438A           4
# R-22             4
# R-407A           3
# R-422A           2
# R-426A           2
# Name: GEIDescription, dtype: int64

# %%
data_df["GEIDescription"].value_counts()
# Out:
# CO2eq       127648
# C02          93977
# CH4          67808
# N2O          67808
# R-410A         134
# R-407C         112
# HFC-134a        80
# R-449A          68
# R-407F          60
# R-404A          41
# R-407H          17
# R-422D          16
# R-448A          16
# R-424A          12
# R-453A           9
# R-438A           4
# R-22             4
# R-407A           3
# R-422A           2
# R-426A           2
# Name: GEIDescription, dtype: int64

# %%
data_df.isna().sum()
# Out:
# Id                                        0
# ClientID                                  0
# ClientDescription                         0
# OrganizationalUnitID                      0
# OrganizationalUnitDescription             0
# OrganizationalUnitTypeID                  0
# OrganizationalUnitTypeDescription         0
# SourceID                              11314
# SourceDescription                     11314
# ValueDate                                 0
# Month                                     0
# Year                                      0
# PeriodID                                  0
# PeriodDescription                         0
# AspectGroupID                             0
# AspectGroupDescription                    0
# FactorID                                  0
# FactorDescription                         0
# AspectID                                  0
# AspectDescription                         0
# Value                                     0
# UnitID                                    0
# UnitDescription                           0
# GEIID                                156341
# GEIDescription                       156341
# LERCodeCodeUnit                      502843
# LERCodeDescription                   502843
# EmitterGEIID                          34606
# EmitterGEIDescription                 34724
# VendorID                              33989
# VendorName                            33989
# RawMaterialGroupID                   514000
# RawMaterialGroupDescription          514000
# RawMaterialOriginID                  514000
# RawMaterialOriginDescription         514000
# DisposalMethodID                     514162
# DisposalMethodDescription            514162
# WaterUsesID                          513911
# WaterUsesDescription                 513911
# WaterOriginID                        513911
# WaterOriginDescription               513911
# ScopeID                              156365
# ScopeDescription                     156365
# FuelTypeID                           514084
# FuelTypeDescription                  514084
# WasteTypeID                          503159
# WasteTypeDescription                 503159
# WasteTreatmentID                     508052
# WasteTreatmentDescription            508052
# TransportID                          502848
# TransportDescription                 502848
# TransportTypeID                      502848
# TransportTypeDescription             502848
# BiogenicEmission                         85
# Renovable                            204676
# new_value                                 0
# dtype: int64

# %%
data_df.head()
# Out:
#        Id  ClientID    ClientDescription  OrganizationalUnitID  \
# 0  7958.0      30.0  Cliente anonimizado                  18.0
# 1  7959.0      30.0  Cliente anonimizado                  18.0
# 2  7960.0      30.0  Cliente anonimizado                  18.0
# 3  7961.0      30.0  Cliente anonimizado                  18.0
# 4  7962.0      30.0  Cliente anonimizado                  18.0
#
#      OrganizationalUnitDescription  OrganizationalUnitTypeID  \
# 0  Unidad organizativa anonimizada                       3.0
# 1  Unidad organizativa anonimizada                       3.0
# 2  Unidad organizativa anonimizada                       3.0
# 3  Unidad organizativa anonimizada                       3.0
# 4  Unidad organizativa anonimizada                       3.0
#
#   OrganizationalUnitTypeDescription  SourceID SourceDescription  ValueDate  \
# 0                           Oficina      18.0     Consumo toner 2017-01-01
# 1                           Oficina      18.0     Consumo toner 2017-02-01
# 2                           Oficina      18.0     Consumo toner 2017-03-01
# 3                           Oficina      18.0     Consumo toner 2017-04-01
# 4                           Oficina      18.0     Consumo toner 2017-05-01
#
#    ...  WasteTypeDescription  WasteTreatmentID  WasteTreatmentDescription  \
# 0  ...                   NaN               NaN                        NaN
# 1  ...                   NaN               NaN                        NaN
# 2  ...                   NaN               NaN                        NaN
# 3  ...                   NaN               NaN                        NaN
# 4  ...                   NaN               NaN                        NaN
#
#   TransportID  TransportDescription TransportTypeID  TransportTypeDescription  \
# 0         NaN                   NaN             NaN                       NaN
# 1         NaN                   NaN             NaN                       NaN
# 2         NaN                   NaN             NaN                       NaN
# 3         NaN                   NaN             NaN                       NaN
# 4         NaN                   NaN             NaN                       NaN
#
#   BiogenicEmission  Renovable new_value
# 0            False      False  0.169863
# 1            False      False  0.153425
# 2            False      False  0.169863
# 3            False      False  0.164384
# 4            False      False  0.169863
#
# [5 rows x 56 columns]

# %%
data_df["ClientDescription"].value_counts()
# Out:
# Cliente anonimizado    514162
# Name: ClientDescription, dtype: int64

# %%
data_df["ClientID"].value_counts().head()
# Out:
# 460.0    341047
# 180.0     43846
# 690.0     42783
# 610.0     24903
# 130.0      5154
# Name: ClientID, dtype: int64

# %%
data_df["PeriodDescription"].value_counts()
# Out:
# Año 2021     210398
# Año 2020     148254
# Año 2019      95951
# Año 2022      43863
# Año 2018       5448
# Año 2017       3373
# FY 2016         948
# FY 2017         888
# FY 2018         775
# Año 2016        654
# FY 2019         615
# FY 2020         568
# FY 2021         492
# Año 2015        412
# FY 2022         289
# Year 2020       284
# Año 2014        261
# Year 2019       215
# Year 2016       166
# Year 2018       153
# Year 2017       143
# Año 2013         12
# Name: PeriodDescription, dtype: int64

# %%
data_df["VendorName"].value_counts()
# Out:
# Solred                                   392143
# ENÉRGYA VM GESTIÓN DE ENERGÍA. S.L.U.     10420
# Endesa Energía S.A                         7908
# Iberdrola Clientes S.A.U                   6874
# Genérico                                   5492
#                                           ...
# ERCI-EMPRESA RECICLAGEM                       1
# Aemsys                                        1
# Ecoplast                                      1
# Recilec                                       1
# INLOGEM                                       1
# Name: VendorName, Length: 317, dtype: int64

# %%
data_df["Month"]
# Out:
# 0         1.0
# 1         2.0
# 2         3.0
# 3         4.0
# 4         5.0
#          ...
# 514266    2.0
# 514267    2.0
# 514268    1.0
# 514269    1.0
# 514270    1.0
# Name: Month, Length: 514162, dtype: float64

# %%
data_df.isna().sum()
# Out:
# Id                                        0
# ClientID                                  0
# ClientDescription                         0
# OrganizationalUnitID                      0
# OrganizationalUnitDescription             0
# OrganizationalUnitTypeID                  0
# OrganizationalUnitTypeDescription         0
# SourceID                              11314
# SourceDescription                     11314
# ValueDate                                 0
# Month                                     0
# Year                                      0
# PeriodID                                  0
# PeriodDescription                         0
# AspectGroupID                             0
# AspectGroupDescription                    0
# FactorID                                  0
# FactorDescription                         0
# AspectID                                  0
# AspectDescription                         0
# Value                                     0
# UnitID                                    0
# UnitDescription                           0
# GEIID                                156341
# GEIDescription                       156341
# LERCodeCodeUnit                      502843
# LERCodeDescription                   502843
# EmitterGEIID                          34606
# EmitterGEIDescription                 34724
# VendorID                              33989
# VendorName                            33989
# RawMaterialGroupID                   514000
# RawMaterialGroupDescription          514000
# RawMaterialOriginID                  514000
# RawMaterialOriginDescription         514000
# DisposalMethodID                     514162
# DisposalMethodDescription            514162
# WaterUsesID                          513911
# WaterUsesDescription                 513911
# WaterOriginID                        513911
# WaterOriginDescription               513911
# ScopeID                              156365
# ScopeDescription                     156365
# FuelTypeID                           514084
# FuelTypeDescription                  514084
# WasteTypeID                          503159
# WasteTypeDescription                 503159
# WasteTreatmentID                     508052
# WasteTreatmentDescription            508052
# TransportID                          502848
# TransportDescription                 502848
# TransportTypeID                      502848
# TransportTypeDescription             502848
# BiogenicEmission                         85
# Renovable                            204676
# new_value                                 0
# dtype: int64

# %%
columns_to_use = ['Id','ClientID','OrganizationalUnitID','OrganizationalUnitTypeDescription',
                  'SourceDescription','Month','Year','PeriodDescription','AspectGroupDescription','FactorDescription',
                  'AspectDescription','UnitDescription','GEIDescription','EmitterGEIDescription','VendorName',
                  'ScopeDescription','BiogenicEmission','new_value']

# %%
data_to_use = data_df[columns_to_use]

# %%
data_to_use.head()
# Out:
#        Id  ClientID  OrganizationalUnitID OrganizationalUnitTypeDescription  \
# 0  7958.0      30.0                  18.0                           Oficina
# 1  7959.0      30.0                  18.0                           Oficina
# 2  7960.0      30.0                  18.0                           Oficina
# 3  7961.0      30.0                  18.0                           Oficina
# 4  7962.0      30.0                  18.0                           Oficina
#
#   SourceDescription  Month    Year PeriodDescription AspectGroupDescription  \
# 0     Consumo toner    1.0  2017.0          Año 2017        Materias primas
# 1     Consumo toner    2.0  2017.0          Año 2017        Materias primas
# 2     Consumo toner    3.0  2017.0          Año 2017        Materias primas
# 3     Consumo toner    4.0  2017.0          Año 2017        Materias primas
# 4     Consumo toner    5.0  2017.0          Año 2017        Materias primas
#
#   FactorDescription AspectDescription UnitDescription GEIDescription  \
# 0   Materias Primas     Consumo toner              kg            NaN
# 1   Materias Primas     Consumo toner              kg            NaN
# 2   Materias Primas     Consumo toner              kg            NaN
# 3   Materias Primas     Consumo toner              kg            NaN
# 4   Materias Primas     Consumo toner              kg            NaN
#
#   EmitterGEIDescription VendorName ScopeDescription BiogenicEmission  \
# 0                   NaN    PCToner              NaN            False
# 1                   NaN    PCToner              NaN            False
# 2                   NaN    PCToner              NaN            False
# 3                   NaN    PCToner              NaN            False
# 4                   NaN    PCToner              NaN            False
#
#    new_value
# 0   0.169863
# 1   0.153425
# 2   0.169863
# 3   0.164384
# 4   0.169863

# %%
data_to_use.isna().sum()
# Out:
# Id                                        0
# ClientID                                  0
# OrganizationalUnitID                      0
# OrganizationalUnitTypeDescription         0
# SourceDescription                     11314
# Month                                     0
# Year                                      0
# PeriodDescription                         0
# AspectGroupDescription                    0
# FactorDescription                         0
# AspectDescription                         0
# UnitDescription                           0
# GEIDescription                       156341
# EmitterGEIDescription                 34724
# VendorName                            33989
# ScopeDescription                     156365
# BiogenicEmission                         85
# new_value                                 0
# dtype: int64

# %%
data_to_use.loc[data_to_use['ScopeDescription'].isna()]
# Out:
#                Id  ClientID  OrganizationalUnitID  \
# 0          7958.0      30.0                  18.0
# 1          7959.0      30.0                  18.0
# 2          7960.0      30.0                  18.0
# 3          7961.0      30.0                  18.0
# 4          7962.0      30.0                  18.0
# ...           ...       ...                   ...
# 514260  1753938.0     690.0                1513.0
# 514262  1753940.0     690.0                1513.0
# 514264  1753942.0     690.0                1513.0
# 514267  1753945.0     700.0                1606.0
# 514270  1753948.0     700.0                1606.0
#
#        OrganizationalUnitTypeDescription            SourceDescription  Month  \
# 0                                Oficina                Consumo toner    1.0
# 1                                Oficina                Consumo toner    2.0
# 2                                Oficina                Consumo toner    3.0
# 3                                Oficina                Consumo toner    4.0
# 4                                Oficina                Consumo toner    5.0
# ...                                  ...                          ...    ...
# 514260                           Oficina   Consumo eléctrico oficinas    4.0
# 514262                           Oficina   Consumo eléctrico oficinas    4.0
# 514264                           Oficina   Consumo eléctrico oficinas    4.0
# 514267                           Oficina  Consumo eléctrico oficinas     2.0
# 514270                           Oficina  Consumo eléctrico oficinas     1.0
#
#           Year PeriodDescription AspectGroupDescription FactorDescription  \
# 0       2017.0          Año 2017        Materias primas   Materias Primas
# 1       2017.0          Año 2017        Materias primas   Materias Primas
# 2       2017.0          Año 2017        Materias primas   Materias Primas
# 3       2017.0          Año 2017        Materias primas   Materias Primas
# 4       2017.0          Año 2017        Materias primas   Materias Primas
# ...        ...               ...                    ...               ...
# 514260  2022.0          Año 2022           Electricidad          Energía
# 514262  2022.0          Año 2022           Electricidad          Energía
# 514264  2022.0          Año 2022           Electricidad          Energía
# 514267  2022.0          Año 2022           Electricidad          Energía
# 514270  2022.0          Año 2022           Electricidad          Energía
#
#         AspectDescription UnitDescription GEIDescription  \
# 0           Consumo toner              kg            NaN
# 1           Consumo toner              kg            NaN
# 2           Consumo toner              kg            NaN
# 3           Consumo toner              kg            NaN
# 4           Consumo toner              kg            NaN
# ...                   ...             ...            ...
# 514260  Consumo eléctrico             kWh            NaN
# 514262  Consumo eléctrico             kWh            NaN
# 514264  Consumo eléctrico             kWh            NaN
# 514267  Consumo eléctrico             kWh            NaN
# 514270  Consumo eléctrico             kWh            NaN
#
#        EmitterGEIDescription                             VendorName  \
# 0                        NaN                                PCToner
# 1                        NaN                                PCToner
# 2                        NaN                                PCToner
# 3                        NaN                                PCToner
# 4                        NaN                                PCToner
# ...                      ...                                    ...
# 514260          Electricidad  ENÉRGYA VM GESTIÓN DE ENERGÍA. S.L.U.
# 514262          Electricidad  ENÉRGYA VM GESTIÓN DE ENERGÍA. S.L.U.
# 514264          Electricidad  ENÉRGYA VM GESTIÓN DE ENERGÍA. S.L.U.
# 514267          Electricidad                       Edp Clientes Sau
# 514270          Electricidad                       Edp Clientes Sau
#
#        ScopeDescription BiogenicEmission    new_value
# 0                   NaN            False     0.169863
# 1                   NaN            False     0.153425
# 2                   NaN            False     0.169863
# 3                   NaN            False     0.164384
# 4                   NaN            False     0.169863
# ...                 ...              ...          ...
# 514260              NaN            False     0.000000
# 514262              NaN            False     0.000000
# 514264              NaN            False     0.000000
# 514267              NaN            False  8022.000000
# 514270              NaN            False  9664.000000
#
# [156365 rows x 18 columns]

# %%
f = lambda x: x.median() if np.issubdtype(x.dtype, np.number) else (x.mode().iloc[0] if len(x.mode())>0 else np.nan)
data_to_use = data_to_use.fillna(data_to_use.groupby('ClientID').transform(f))

# %%
data_to_use['SourceDescription'].value_counts()
# Out:
# Consumo eléctrico oficinas              15550
# Consumo eléctrico                       14502
# Suministro eléctrico                     7069
# Consumo gasóleo A                        4738
# Consumo agua                             3305
#                                         ...
# Productos enológicos obsoletos              1
# Lodos de lavado y limpieza Verinsur         1
# Sacos Big Bag contaminados                  1
# Cartuchos tinta                             1
# 0007078835341313527 adblue                  1
# Name: SourceDescription, Length: 3932, dtype: int64

# %%
data_to_use.isna().sum()
# Out:
# Id                                      0
# ClientID                                0
# OrganizationalUnitID                    0
# OrganizationalUnitTypeDescription       0
# SourceDescription                      12
# Month                                   0
# Year                                    0
# PeriodDescription                       0
# AspectGroupDescription                  0
# FactorDescription                       0
# AspectDescription                       0
# UnitDescription                         0
# GEIDescription                         26
# EmitterGEIDescription                  26
# VendorName                           1087
# ScopeDescription                       26
# BiogenicEmission                        0
# new_value                               0
# dtype: int64

# %%
data_to_use = data_to_use.fillna(data_to_use.mode().iloc[0])

# %%
data_to_use.isna().sum()
# Out:
# Id                                   0
# ClientID                             0
# OrganizationalUnitID                 0
# OrganizationalUnitTypeDescription    0
# SourceDescription                    0
# Month                                0
# Year                                 0
# PeriodDescription                    0
# AspectGroupDescription               0
# FactorDescription                    0
# AspectDescription                    0
# UnitDescription                      0
# GEIDescription                       0
# EmitterGEIDescription                0
# VendorName                           0
# ScopeDescription                     0
# BiogenicEmission                     0
# new_value                            0
# dtype: int64

# %%
data_to_use.dtypes
# Out:
# Id                                   float64
# ClientID                             float64
# OrganizationalUnitID                 float64
# OrganizationalUnitTypeDescription     object
# SourceDescription                     object
# Month                                float64
# Year                                 float64
# PeriodDescription                     object
# AspectGroupDescription                object
# FactorDescription                     object
# AspectDescription                     object
# UnitDescription                       object
# GEIDescription                        object
# EmitterGEIDescription                 object
# VendorName                            object
# ScopeDescription                      object
# BiogenicEmission                        bool
# new_value                            float64
# dtype: object

# %%
data_to_use
# Out:
#                Id  ClientID  OrganizationalUnitID  \
# 0          7958.0      30.0                  18.0
# 1          7959.0      30.0                  18.0
# 2          7960.0      30.0                  18.0
# 3          7961.0      30.0                  18.0
# 4          7962.0      30.0                  18.0
# ...           ...       ...                   ...
# 514266  1753944.0     700.0                1606.0
# 514267  1753945.0     700.0                1606.0
# 514268  1753946.0     700.0                1606.0
# 514269  1753947.0     700.0                1606.0
# 514270  1753948.0     700.0                1606.0
#
#        OrganizationalUnitTypeDescription            SourceDescription  Month  \
# 0                                Oficina                Consumo toner    1.0
# 1                                Oficina                Consumo toner    2.0
# 2                                Oficina                Consumo toner    3.0
# 3                                Oficina                Consumo toner    4.0
# 4                                Oficina                Consumo toner    5.0
# ...                                  ...                          ...    ...
# 514266                           Oficina  Consumo eléctrico oficinas     2.0
# 514267                           Oficina  Consumo eléctrico oficinas     2.0
# 514268                           Oficina  Consumo eléctrico oficinas     1.0
# 514269                           Oficina  Consumo eléctrico oficinas     1.0
# 514270                           Oficina  Consumo eléctrico oficinas     1.0
#
#           Year PeriodDescription AspectGroupDescription FactorDescription  \
# 0       2017.0          Año 2017        Materias primas   Materias Primas
# 1       2017.0          Año 2017        Materias primas   Materias Primas
# 2       2017.0          Año 2017        Materias primas   Materias Primas
# 3       2017.0          Año 2017        Materias primas   Materias Primas
# 4       2017.0          Año 2017        Materias primas   Materias Primas
# ...        ...               ...                    ...               ...
# 514266  2022.0          Año 2022           Electricidad         Emisiones
# 514267  2022.0          Año 2022           Electricidad          Energía
# 514268  2022.0          Año 2022           Electricidad         Emisiones
# 514269  2022.0          Año 2022           Electricidad         Emisiones
# 514270  2022.0          Año 2022           Electricidad          Energía
#
#         AspectDescription UnitDescription GEIDescription  \
# 0           Consumo toner              kg          CO2eq
# 1           Consumo toner              kg          CO2eq
# 2           Consumo toner              kg          CO2eq
# 3           Consumo toner              kg          CO2eq
# 4           Consumo toner              kg          CO2eq
# ...                   ...             ...            ...
# 514266  Consumo eléctrico               t          CO2eq
# 514267  Consumo eléctrico             kWh          CO2eq
# 514268  Consumo eléctrico               t            C02
# 514269  Consumo eléctrico               t          CO2eq
# 514270  Consumo eléctrico             kWh          CO2eq
#
#        EmitterGEIDescription        VendorName ScopeDescription  \
# 0               Electricidad           PCToner        Alcance 3
# 1               Electricidad           PCToner        Alcance 3
# 2               Electricidad           PCToner        Alcance 3
# 3               Electricidad           PCToner        Alcance 3
# 4               Electricidad           PCToner        Alcance 3
# ...                      ...               ...              ...
# 514266          Electricidad  Edp Clientes Sau        Alcance 2
# 514267          Electricidad  Edp Clientes Sau        Alcance 1
# 514268          Electricidad  Edp Clientes Sau        Alcance 2
# 514269          Electricidad  Edp Clientes Sau        Alcance 2
# 514270          Electricidad  Edp Clientes Sau        Alcance 1
#
#         BiogenicEmission    new_value
# 0                  False     0.169863
# 1                  False     0.153425
# 2                  False     0.169863
# 3                  False     0.164384
# 4                  False     0.169863
# ...                  ...          ...
# 514266             False     0.962640
# 514267             False  8022.000000
# 514268             False   115.968000
# 514269             False   115.968000
# 514270             False  9664.000000
#
# [514162 rows x 18 columns]

# %%
data_to_use.to_csv("drive/MyDrive/Capstone/data_to_use.csv")
